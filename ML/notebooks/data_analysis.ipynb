# %% [markdown]
# # Competance Project

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import display

# %% [markdown]
# ### About Dataset
#
# [https://www.kaggle.com/datasets/g1llar/poland-olx-house-price-q122](https://www.kaggle.com/datasets/g1llar/poland-olx-house-price-q122)
#
# Analyses of the pricing and brand based on [OLX Portal](https://www.olx.pl/nieruchomosci/mieszkania/)
#
# Features description:
# - offer_title: offer title
# - price: price in PLN
# - price_per_meter: price in PLN for square meter
# - offer_type: as value name
# - floor: floor number for -1 --> basement, 0 --> Ground Floor, 10 --> floor 10+, 11 --> attic
# - area: area in square meters
# - rooms: number of rooms for 4 --> rooms 4+
# - offer_type_of_building: as value name
# - market: as value name
# - city_name: name of city where home is
# - voivodeship: name of voivodeship where home is
# - month: data download month
# - year: data download year
# - population: city population where home is
# - longitude``latitude: city coordinates

# %% [markdown]
# The original file has bad encoding. Scraped data should be interpreted as UTF-8 and added features (voivodeship) as ANSI.
#
# Possible fix:
# 1. Convert to ANSI
# 2. Replace all 'Świętokrzyskie' to 'Swietokrzyskie'
# 3. Interpret as UTF-8
# 4. Replace all  'Swietokrzyskie' to 'Świętokrzyskie'

# %%
PATH = "../data/raw/olx_house_price_Q122.csv"

# %%
df_raw = pd.read_csv(PATH)

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000):
        display(df)

# %%
df_raw.shape
# Out:
# (62818, 16)

# %%
display_all(df_raw.tail().T)
# Out:
#                                                     62813  \
# offer_title             Mieszkanie 4-pokojowe 57m2 parter
# price                                            230000.0
# price_per_meter                                   4035.09
# offer_type                                        Private
# floor                                                 0.0
# area                                                 57.0
# rooms                                                   4
# offer_type_of_building                      Housing Block
# market                                        aftermarket
# city_name                                      Złocieniec
# voivodeship                                West Pomerania
# month                                               March
# year                                                 2022
# population                                          13224
# longitude                                       16.012066
# latitude                                         53.53107
#
#                                                                     62814  \
# offer_title             Mieszkanie 4-pokojowe spółdz. własność. z umeb...
# price                                                            390000.0
# price_per_meter                                                   5735.29
# offer_type                                                        Private
# floor                                                                 1.0
# area                                                                 68.0
# rooms                                                                   4
# offer_type_of_building                                      Housing Block
# market                                                        aftermarket
# city_name                                                           Łobez
# voivodeship                                                West Pomerania
# month                                                               March
# year                                                                 2022
# population                                                          10438
# longitude                                                       15.621349
# latitude                                                        53.639119
#
#                                                  62815  \
# offer_title             Mieszkanie z lokalem użytkowym
# price                                         330000.0
# price_per_meter                                2704.92
# offer_type                                     Private
# floor                                              1.0
# area                                             122.0
# rooms                                                4
# offer_type_of_building                           Other
# market                                     aftermarket
# city_name                                      Świdwin
# voivodeship                             West Pomerania
# month                                            March
# year                                              2022
# population                                       15725
# longitude                                    15.777351
# latitude                                     53.774704
#
#                                               62816  \
# offer_title             Mieszkanie 80m2  przy lesie
# price                                      830000.0
# price_per_meter                             10375.0
# offer_type                                  Private
# floor                                           1.0
# area                                           80.0
# rooms                                             4
# offer_type_of_building                Housing Block
# market                                  aftermarket
# city_name                               Świnoujście
# voivodeship                          West Pomerania
# month                                         March
# year                                           2022
# population                                    41371
# longitude                                  14.25107
# latitude                                  53.909748
#
#                                                                     62817
# offer_title             Duże, komfortowe mieszkanie blisko Parku Zdroj...
# price                                                            990000.0
# price_per_meter                                                   9437.56
# offer_type                                                        Private
# floor                                                                 3.0
# area                                                                104.9
# rooms                                                                   4
# offer_type_of_building                                      Housing Block
# market                                                        aftermarket
# city_name                                                     Świnoujście
# voivodeship                                                West Pomerania
# month                                                               March
# year                                                                 2022
# population                                                          41371
# longitude                                                        14.25107
# latitude                                                        53.909748

# %%
display_all(df_raw.describe(include="all").T)
# Out:
#                           count unique                  top   freq  \
# offer_title               62818  29138  Sprzedam mieszkanie   1855
# price                   62818.0    NaN                  NaN    NaN
# price_per_meter         62818.0    NaN                  NaN    NaN
# offer_type                62818      2              Private  45449
# floor                   61331.0    NaN                  NaN    NaN
# area                    61331.0    NaN                  NaN    NaN
# rooms                   62818.0    NaN                  NaN    NaN
# offer_type_of_building    61331      5        Housing Block  43868
# market                    62818      2          aftermarket  55171
# city_name                 62818    611             Warszawa   4297
# voivodeship               62818     16              Masovia   9292
# month                     62818      3                March  21895
# year                    62818.0    NaN                  NaN    NaN
# population              62818.0    NaN                  NaN    NaN
# longitude               62818.0    NaN                  NaN    NaN
# latitude                62818.0    NaN                  NaN    NaN
#
#                                  mean             std        min        25%  \
# offer_title                       NaN             NaN        NaN        NaN
# price                   399405.854865  2023250.514224        1.0   260000.0
# price_per_meter           7596.442371    36561.779747       0.02     5250.0
# offer_type                        NaN             NaN        NaN        NaN
# floor                        2.399749         2.15051       -1.0        1.0
# area                        91.251837     3153.663628        1.0       42.0
# rooms                        2.515378        0.826473        1.0        2.0
# offer_type_of_building            NaN             NaN        NaN        NaN
# market                            NaN             NaN        NaN        NaN
# city_name                         NaN             NaN        NaN        NaN
# voivodeship                       NaN             NaN        NaN        NaN
# month                             NaN             NaN        NaN        NaN
# year                           2022.0             0.0     2022.0     2022.0
# population              314967.042536   454366.944035     1328.0    33967.0
# longitude                   19.161558        2.139698   14.25107  17.565228
# latitude                    51.819109        1.322616  49.296945  50.679307
#
#                               50%        75%          max
# offer_title                   NaN        NaN          NaN
# price                    345000.0   460000.0  504151616.0
# price_per_meter          6576.845    8766.93   9002707.43
# offer_type                    NaN        NaN          NaN
# floor                         2.0        3.0         11.0
# area                         51.2       63.0     399000.0
# rooms                         2.0        3.0          4.0
# offer_type_of_building        NaN        NaN          NaN
# market                        NaN        NaN          NaN
# city_name                     NaN        NaN          NaN
# voivodeship                   NaN        NaN          NaN
# month                         NaN        NaN          NaN
# year                       2022.0     2022.0       2022.0
# population               103997.0   402465.0    1744351.0
# longitude               19.272156  20.930831    23.887382
# latitude                51.768732  52.807175    54.790132

# %%
df_raw.corr()
# Out:
# /tmp/ipykernel_112896/3162014398.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_raw.corr()
#                     price  price_per_meter     floor      area     rooms  \
# price            1.000000         0.981488  0.001277  0.000295  0.040408
# price_per_meter  0.981488         1.000000  0.004335 -0.002520 -0.017683
# floor            0.001277         0.004335  1.000000 -0.005635  0.013448
# area             0.000295        -0.002520 -0.005635  1.000000 -0.000252
# rooms            0.040408        -0.017683  0.013448 -0.000252  1.000000
# year                  NaN              NaN       NaN       NaN       NaN
# population       0.050284         0.053226  0.118033  0.003224 -0.070297
# longitude        0.001003         0.005617  0.041130 -0.001409  0.007835
# latitude         0.009655         0.007212 -0.032957  0.007318  0.036158
#
#                  year  population  longitude  latitude
# price             NaN    0.050284   0.001003  0.009655
# price_per_meter   NaN    0.053226   0.005617  0.007212
# floor             NaN    0.118033   0.041130 -0.032957
# area              NaN    0.003224  -0.001409  0.007318
# rooms             NaN   -0.070297   0.007835  0.036158
# year              NaN         NaN        NaN       NaN
# population        NaN    1.000000   0.182673 -0.022828
# longitude         NaN    0.182673   1.000000 -0.172376
# latitude          NaN   -0.022828  -0.172376  1.000000

# %% [markdown]
# ### Look at the data

# %% [markdown]
# #### Missing values

# %%
display_all(
    pd.DataFrame(
        {
            "number": df_raw.isnull().sum(),
            "percentage": df_raw.isnull().sum().sort_values(ascending=False)
            / len(df_raw),
        }
    )
)
# Out:
#                         number  percentage
# area                      1487    0.023672
# city_name                    0    0.000000
# floor                     1487    0.023672
# latitude                     0    0.000000
# longitude                    0    0.000000
# market                       0    0.000000
# month                        0    0.000000
# offer_title                  0    0.000000
# offer_type                   0    0.000000
# offer_type_of_building    1487    0.023672
# population                   0    0.000000
# price                        0    0.000000
# price_per_meter              0    0.000000
# rooms                        0    0.000000
# voivodeship                  0    0.000000
# year                         0    0.000000

# %%
df_raw.describe(include="all").T
# Out:
#                           count unique                  top   freq  \
# offer_title               62818  29138  Sprzedam mieszkanie   1855
# price                   62818.0    NaN                  NaN    NaN
# price_per_meter         62818.0    NaN                  NaN    NaN
# offer_type                62818      2              Private  45449
# floor                   61331.0    NaN                  NaN    NaN
# area                    61331.0    NaN                  NaN    NaN
# rooms                   62818.0    NaN                  NaN    NaN
# offer_type_of_building    61331      5        Housing Block  43868
# market                    62818      2          aftermarket  55171
# city_name                 62818    611             Warszawa   4297
# voivodeship               62818     16              Masovia   9292
# month                     62818      3                March  21895
# year                    62818.0    NaN                  NaN    NaN
# population              62818.0    NaN                  NaN    NaN
# longitude               62818.0    NaN                  NaN    NaN
# latitude                62818.0    NaN                  NaN    NaN
#
#                                  mean             std        min        25%  \
# offer_title                       NaN             NaN        NaN        NaN
# price                   399405.854865  2023250.514224        1.0   260000.0
# price_per_meter           7596.442371    36561.779747       0.02     5250.0
# offer_type                        NaN             NaN        NaN        NaN
# floor                        2.399749         2.15051       -1.0        1.0
# area                        91.251837     3153.663628        1.0       42.0
# rooms                        2.515378        0.826473        1.0        2.0
# offer_type_of_building            NaN             NaN        NaN        NaN
# market                            NaN             NaN        NaN        NaN
# city_name                         NaN             NaN        NaN        NaN
# voivodeship                       NaN             NaN        NaN        NaN
# month                             NaN             NaN        NaN        NaN
# year                           2022.0             0.0     2022.0     2022.0
# population              314967.042536   454366.944035     1328.0    33967.0
# longitude                   19.161558        2.139698   14.25107  17.565228
# latitude                    51.819109        1.322616  49.296945  50.679307
#
#                               50%        75%          max
# offer_title                   NaN        NaN          NaN
# price                    345000.0   460000.0  504151616.0
# price_per_meter          6576.845    8766.93   9002707.43
# offer_type                    NaN        NaN          NaN
# floor                         2.0        3.0         11.0
# area                         51.2       63.0     399000.0
# rooms                         2.0        3.0          4.0
# offer_type_of_building        NaN        NaN          NaN
# market                        NaN        NaN          NaN
# city_name                     NaN        NaN          NaN
# voivodeship                   NaN        NaN          NaN
# month                         NaN        NaN          NaN
# year                       2022.0     2022.0       2022.0
# population               103997.0   402465.0    1744351.0
# longitude               19.272156  20.930831    23.887382
# latitude                51.768732  52.807175    54.790132

# %%
df_raw[df_raw["floor"].isnull()].describe(include="all").T
# Out:
#                          count unique                  top  freq  \
# offer_title               1487    672  Sprzedam mieszkanie    38
# price                   1487.0    NaN                  NaN   NaN
# price_per_meter         1487.0    NaN                  NaN   NaN
# offer_type                1487      2              Private   910
# floor                      0.0    NaN                  NaN   NaN
# area                       0.0    NaN                  NaN   NaN
# rooms                   1487.0    NaN                  NaN   NaN
# offer_type_of_building       0      0                  NaN   NaN
# market                    1487      2          aftermarket  1149
# city_name                 1487    228             Warszawa   136
# voivodeship               1487     16              Masovia   238
# month                     1487      3                March   518
# year                    1487.0    NaN                  NaN   NaN
# population              1487.0    NaN                  NaN   NaN
# longitude               1487.0    NaN                  NaN   NaN
# latitude                1487.0    NaN                  NaN   NaN
#
#                                  mean            std        min        25%  \
# offer_title                       NaN            NaN        NaN        NaN
# price                   417619.282112  351042.733482     1190.0   260000.0
# price_per_meter           8231.820545   21830.908497      16.36    4814.81
# offer_type                        NaN            NaN        NaN        NaN
# floor                             NaN            NaN        NaN        NaN
# area                              NaN            NaN        NaN        NaN
# rooms                        2.621385       0.917836        1.0        2.0
# offer_type_of_building            NaN            NaN        NaN        NaN
# market                            NaN            NaN        NaN        NaN
# city_name                         NaN            NaN        NaN        NaN
# voivodeship                       NaN            NaN        NaN        NaN
# month                             NaN            NaN        NaN        NaN
# year                           2022.0            0.0     2022.0     2022.0
# population              331379.677875  500448.253548     1993.0    30678.5
# longitude                    19.32132       2.161993  14.550962  17.747227
# latitude                    51.720799       1.255116  49.296945  50.633797
#
#                               50%        75%        max
# offer_title                   NaN        NaN        NaN
# price                    340000.0   473806.0  4200000.0
# price_per_meter            6200.0     8500.0   425000.0
# offer_type                    NaN        NaN        NaN
# floor                         NaN        NaN        NaN
# area                          NaN        NaN        NaN
# rooms                         3.0        3.0        4.0
# offer_type_of_building        NaN        NaN        NaN
# market                        NaN        NaN        NaN
# city_name                     NaN        NaN        NaN
# voivodeship                   NaN        NaN        NaN
# month                         NaN        NaN        NaN
# year                       2022.0     2022.0     2022.0
# population                99752.0   402465.0  1744351.0
# longitude               19.456991  21.006725  23.887382
# latitude                51.768732  52.604647   54.53915

# %% [markdown]
# Area can be calculated from `price` and `price_per_meter`.
# Houses with missing values are approx. 8% more expensive

# %% [markdown]
# #### Types

# %%
df_raw.dtypes
# Out:
# offer_title                object
# price                     float64
# price_per_meter           float64
# offer_type                 object
# floor                     float64
# area                      float64
# rooms                       int64
# offer_type_of_building     object
# market                     object
# city_name                  object
# voivodeship                object
# month                      object
# year                        int64
# population                  int64
# longitude                 float64
# latitude                  float64
# dtype: object

# %% [markdown]
# #### Features

# %%
to_be_ploted = [
    "offer_title",
    "offer_type",
    "floor",
    "rooms",
    "offer_type_of_building",
    "market",
    "city_name",
    "voivodeship",
    "month",
    "year",
]

for feature in to_be_ploted:
    plt.figure()
    df_raw[feature].value_counts().sort_values(ascending=False).head(20).plot(
        kind="barh", title=feature
    )

plt.show()
